# %% [markdown]
# # **ML 14**
# **┗ 상권분석**
# ---
# > **목차(Context)**
#
# * 문제상황 및 데이터 살펴보기
# * 문제해결 프로세스 정의
# * 🥉Session 1 - 「상권 분석 데이터 이해」
# * 🥈Session 2 - 「주소 기반 상권 분석」
# * 🥇Session 3 - 「신규 진입 상권 탐색」

# %%
# ▶ Warnings 제거
import warnings
warnings.filterwarnings('ignore')

# ▶ Google drive mount or 폴더 클릭 후 구글드라이브 연결
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# ▶ 경로 설정
import os
os.chdir('/content/drive/MyDrive/데이터분석/파이썬_실습/ML 실습/ML실습/ML실습/14_상권분석')
os.getcwd()
# Out:
# '/content/drive/MyDrive/데이터분석/파이썬_실습/ML 실습/ML실습/ML실습/14_상권분석'

# %% [markdown]
# ## **문제상황 및 데이터 살펴보기**
# ---
# > **시나리오** 🗺🥪 (매장관리자,  상권분석가)
#
# ```
# A브랜드는 꽤 잘나가는 체인점을 운영하고 있다. 이번에 거금을 들여 신규점포 출점을 기획하고 있다.
# 대부분의 상권에는 다른 점포들이 입점해 있기 때문에 최대한 상권이 겹치지 않는 곳을 후보지로 선정하려고 한다.
#
# ```

# %% [markdown]
# > **데이터 살펴보기**
#
# * 미국 Subway 위치 정보 데이터
# * 데이터 명세 ⬇
#
# |name|street_address|city|state|zip_code|country|latitude|longitude|
# |:---:|:---:|:---:|:---:|:---:|:---:|:---:|:---:|
# |상호명|거리주소|도시|주|우편번호|나라|위도|경도|

# %%
# ▶ Data read
import pandas as pd
df = pd.read_csv('14_market_analysis.csv')
df.head(2)
# Out:
#      name                                                url  \
# 0  Subway  http://order.subway.com/Stores/Redirect.aspx?s...
# 1  Subway  http://order.subway.com/Stores/Redirect.aspx?s...
#
#           street_address        city state zip_code country  phone_number_1  \
# 0  1800 Duke St, Ste 100  Alexandria    VA    22314     USA             NaN
# 1          1512 King St,  Alexandria    VA    22301     USA             NaN
#
#    phone_number_2  fax_1  ...  email_2  website  \
# 0             NaN    NaN  ...      NaN      NaN
# 1             NaN    NaN  ...      NaN      NaN
#
#                                           open_hours  latitude longitude  \
# 0  Monday 7:00 AM - 7:00 PM, Tuesday 7:00 AM - 7:...   38.8043  -77.0611
# 1  Sunday 9:00 AM - 8:00 PM, Monday 7:00 AM - 9:0...   38.8062  -77.0565
#
#    facebook  twitter  instagram  pinterest  youtube
# 0       NaN      NaN        NaN        NaN      NaN
# 1       NaN      NaN        NaN        NaN      NaN
#
# [2 rows x 22 columns]

# %% [markdown]
# ## **문제해결 프로세스 정의**
# ---
# > **문제정의**
#
# ```
# ▶ 핵심점포 입점 지역 불분명
# ```
#
# > **기대효과**
#
# ```
# ▶ 핵심점포 입점 지역 확정
# ```
#
# > **해결방안**
#
# ```
# ▶ 상권 분석을 통한 입지 선정
# ▶ Session 1 🥉
#  - Data 전처리 및 상권 Data(위도, 경도) 이해
# ▶ Session 2 🥈
#  - 밀집도 분석(State, City)
# ▶ Session 3 🥇
#  - 가설 수립 후 상권 전략 기획
# ```
#
# > **성과측정**
#
# ```
# ▶ 입점 후 매출 모니터링
# ```
#
# > **현업적용**
#
# ```
# ▶ 핵심고객 및 핵심상권 정의
# ▶ 핵심상권의 소비형태 파악
# ▶ 경쟁사 분석 (※ 경쟁사 대비 강점/약점)
# ▶ 입점 후 전략 기획
# ```
#
# > **주요 코드 미리 살펴보기**
#
# ```
# ▶ session 1 → folium.Map(location=[위도,경도]), MarkerCluster()
# MarkerCluster(): 특정 지역의 모여있는 데이터 숫자를 표기해줌)
# ▶ session 2 → plt.bar, reset_index(), pd.merge()
# ▶ session 3 → str.contains()
# ```

# %% [markdown]
# ## **🥉Session 1**
# **┗ 상권 분석 데이터 이해**
# ---

# %% [markdown]
# ### · Data 전처리
# ---
# * 수집된 데이터의 기본 정보들을 확인
#
#   (1) Data shape(형태) 확인
#
#   (2) Data type 확인
#
#   (3) Null값 확인 (※ 빈 값의 Data)
#
#   (4) Outlier 확인 (※ 정상적인 범주를 벗어난 Data)

# %%
# ▶ Data 형태 확인
# ▶ 25,533 row, 22 col로 구성됨
print('df', df.shape)
# Out:
# df (25533, 22)

# %%
# ▶ Data type 확인
df.info()
 #Null 값이 꽤 있는 것으로 판단됨
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25533 entries, 0 to 25532
# Data columns (total 22 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            25533 non-null  object
#  1   url             24017 non-null  object
#  2   street_address  25533 non-null  object
#  3   city            25533 non-null  object
#  4   state           25533 non-null  object
#  5   zip_code        25533 non-null  object
#  6   country         25533 non-null  object
#  7   phone_number_1  0 non-null      float64
#  8   phone_number_2  0 non-null      float64
#  9   fax_1           0 non-null      float64
#  10  fax_2           0 non-null      float64
#  11  email_1         0 non-null      float64
#  12  email_2         0 non-null      float64
#  13  website         0 non-null      float64
#  14  open_hours      25395 non-null  object
#  15  latitude        25533 non-null  float64
#  16  longitude       25533 non-null  float64
#  17  facebook        0 non-null      float64
#  18  twitter         0 non-null      float64
#  19  instagram       0 non-null      float64
#  20  pinterest       0 non-null      float64
#  21  youtube         0 non-null      float64
# dtypes: float64(14), object(8)
# memory usage: 4.3+ MB

# %%
# ▶ Null 값 확인
print(df.isnull().sum())
# Out:
# name                  0
# url                1516
# street_address        0
# city                  0
# state                 0
# zip_code              0
# country               0
# phone_number_1    25533
# phone_number_2    25533
# fax_1             25533
# fax_2             25533
# email_1           25533
# email_2           25533
# website           25533
# open_hours          138
# latitude              0
# longitude             0
# facebook          25533
# twitter           25533
# instagram         25533
# pinterest         25533
# youtube           25533
# dtype: int64

# %% [markdown]
# ### · 상권 분석 Data
# ---

# %%
# ▶ 필요한 데이터만 추출
df=df[['name', 'street_address','city','state', 'zip_code', 'country', 'latitude', 'longitude']]
df.head(5)
# Out:
#      name                                  street_address        city state  \
# 0  Subway                           1800 Duke St, Ste 100  Alexandria    VA
# 1  Subway                                   1512 King St,  Alexandria    VA
# 2  Subway                            2361 Eisenhower Ave,  Alexandria    VA
# 3  Subway                      320 King Street, 1st Floor  Alexandria    VA
# 4  Subway  5836 N. Kings Hwy, Suite A, Huntington Station  Alexandria    VA
#
#   zip_code country  latitude  longitude
# 0    22314     USA   38.8043   -77.0611
# 1    22301     USA   38.8062   -77.0565
# 2    22314     USA   38.8012   -77.0691
# 3    22314     USA   38.8045   -77.0433
# 4    22303     USA   38.7903   -77.0769

# %%
# ▶ Null 값 확인
df.isnull().sum()
# Out:
# name              0
# street_address    0
# city              0
# state             0
# zip_code          0
# country           0
# latitude          0
# longitude         0
# dtype: int64

# %%
# ▶ 총 도시 수 확인(7,286)
df['city'].value_counts()
# Out:
# Houston         232
# Chicago         168
# San Antonio     134
# Los Angeles     129
# Las Vegas       123
#                ...
# Onsted            1
# Horton            1
# Spring Arbor      1
# Morenci           1
# Forks             1
# Name: city, Length: 7286, dtype: int64

# %%
# ▶ 총 주(State) 수 확인(52)
len(df['state'].value_counts())
# Out:
# 52

# %%
df.head(1)
# Out:
#      name         street_address        city state zip_code country  latitude  \
# 0  Subway  1800 Duke St, Ste 100  Alexandria    VA    22314     USA   38.8043
#
#    longitude
# 0   -77.0611

# %%
# ▶ 위도, 경도 활용 특정 좌표 Mapping (City - Alecandria)
 # folium.Map(location=[위도, 경도], zoom_start = 11)
import folium
m = folium.Map(location=[38.8043, -77.0611], zoom_start=12)         #zoom_start가 작을수록 멀리서봄
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bb0f716263a173c820801377880aa385 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bb0f716263a173c820801377880aa385&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bb0f716263a173c820801377880aa385 = L.map(
#                 &quot;map_bb0f716263a173c820801377880aa385&quot;,
#                 {
#                     center: [38.8043, -77.0611],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cf8d5f7509aeeef284ae87ef8e03a420 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_bb0f716263a173c820801377880aa385);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# ▶ 특정 도시에 있는 모든 점포 Market 표시하기
 #여기서는 Huston
df_city = df[df['city']=='Houston']
df_city.head(5)
# Out:
#          name                                   street_address     city state  \
# 11979  Subway                                686 N Jackson St,  Houston    MS
# 15519  Subway                        801 S. Sam Houston Blvd.,  Houston    MO
# 21022  Subway     3040 FM 1960 E, Ste 152, Cypress Landing S/C  Houston    TX
# 21027  Subway               17225 Crosby Hwy, Shell Truck Stop  Houston    TX
# 21072  Subway  14455 Cullen Blvd, #104, Cullen Shopping Center  Houston    TX
#
#       zip_code country  latitude  longitude
# 11979    38851     USA   33.9048   -89.0011
# 15519    65483     USA   37.3200   -91.9592
# 21022    77073     USA   30.0201   -95.3808
# 21027    77049     USA   29.8523   -95.1277
# 21072    77047     USA   29.5978   -95.3524

# %%
#df.loc[인덱스번호, '가져올 컬럼명']
sub_lat2 =  df_city.loc[11979,'latitude']
sub_lat2
# Out:
# 33.9048

# %%
# ▶ 특정 도시에 있는 모든 점포 Market 표시하기
 #여기서는 Houston

m = folium.Map(location=[29.5978, -95.3524], zoom_start=12)

for i in df_city.index:
    sub_lat =  df_city.loc[i,'latitude']            #iloc는 번호로, loc는 그 자체를 활용
    sub_long = df_city.loc[i,'longitude']

    title = df_city.loc[i,'street_address']         #street_address를 가져옴

    # ▶ 지도에 데이터 찍어서 보여주기
     #tooltip으로 마우스를 갖다 대면 어떤 값을 표시되게 할지 지정
     #add_to(변수명) 으로 변수명에서 해당 함수를 실행시켜라
    folium.Marker([sub_lat,sub_long],tooltip = title).add_to(m)

# ▶ 한글이 안나오는 오류가 있으면 html로 trouble shooting
    # ▶ m.save('example.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_48377ac768a1e131885f5ab63b01664c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_48377ac768a1e131885f5ab63b01664c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_48377ac768a1e131885f5ab63b01664c = L.map(
#                 &quot;map_48377ac768a1e131885f5ab63b01664c&quot;,
#                 {
#                     center: [29.5978, -95.3524],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c3550cee310c3f8aacaa57d891bf2b5a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_48377ac768a1e131885f5ab63b01664c);
#
#
#             var marker_552cd3c1c398d0c6e3d8262823560e37 = L.marker(
#                 [33.9048, -89.0011],
#                 {}
#             ).addTo(map_48377ac768a1e131885f5ab63b01664c);
#
#
#             marker_552cd3c1c398d0c6e3d8262823560e37.bindTooltip(
#                 `&lt;div&gt;
#                      686 N Jackson St,
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ce9099034ab9fd4ab8f846eb3c3a3ed9 = L.marker(
#                 [37.32, -91.9592],
#                 {}
#             ).addTo(map_48377ac768a1e131885f5ab63b01664c);
#
#
#             marker_ce9099034ab9fd4ab8f846eb3c3a3ed9.bindTooltip(
#                 `&lt;div&gt;
#                      801 S. Sam Houston Blvd.,
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_dab9357d918dba689c855b33e8d9c31f = L.marker(
#                 [30.0201, -95.3808],
#                 {}
#             ).addTo(map_48377ac768a1e131885f5ab63b01664c);
#
#
#             marker_dab9357d918dba689c855b33e8d9c31f.bindTooltip(
#                 `&lt;div&gt;
#                      3040 FM 1960 E, Ste 152, Cypress Landing S/C
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_7382a6f8eac236de801ec76cdf1224ea = L.marker(
#                 [29.8523, -95.1277],
#                 {}
#             ).addTo(map_48377ac768a1e131885f5ab63b01664c);
#
#
#             marker_7382a6f8eac236de801ec76cdf1224ea.bindTooltip(
#                 `&lt;div&gt;
#                      17225 Crosby Hwy, Shell Truck Stop
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_209fadfc08f9f0f444b509e04c1a4664 = L.marker(
#                 [29.5978, -95.3524],
#                 {}
#             ).addTo(map_48377ac768a1e131885f5ab63b01664c);
#
#
#             marker_209fadfc08f9f0f444b509e04c1a4664.bindTooltip(
#                 `&lt;div&gt;
#                      14455 Cullen Blvd, #104, Cullen Shopping Center
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_cc31577a91a0227ef2c4a4715c7d45e5 = L.marker(
#                 [29.6117, -95.3881],
#                 {}
#             ).addTo(map_48377ac768a1e131885f5ab63b01664c);
#
#
#             marker_cc31577a91a0227ef2c4a4715c7d45e5.bindTooltip(
#                 `&lt;div&gt;
#                      12602 S Freeway/Hwy 288, Texaco C-Store
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_47ad265a21150d2c1efb8ef17d169ed9 = L.marker(
#                 [29.5984, -95.2648],
#                 {}
#             ).addTo(map_48377ac768a1e131885f5ab63b01664c);
#
#
#             marker_47ad265a21150d2c1efb8ef17d169ed9.bindTooltip(
#                 `&lt;div&gt;
#                      10555 Pearland Parkway, Suite C
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_17fc48b67d5b13fc02148bb63a92784e = L.marker(
#                 [29.6244, -95.285],
#                 {}
#             ).addTo(map_48377ac768a1e131885f5ab63b01664c);
#
#
#             marker_17fc48b67d5b13fc02148bb63a92784e.bindTooltip(
#                 `&lt;div&gt;
#                      9715 Telephone Road, Rosewood Shopping Center
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_67806d302d379d9bde66ba925086074b = L.marker(
#                 [29.654, -95.2767],
#                 {}
#             ).addTo(map_48377ac768a1e131885f5ab63b01664c);
#
#
#             marker_67806d302d379d9bde66ba925086074b.bindTooltip(
#                 `&lt;div&gt;
#                      7800 Airport Blvd, Gate 46, William P Hobby Airport
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_6e42bfff16fcea2f5d6158027279752b = L.marker(
#                 [29.603, -95.2481],
#                 {}

# %%
from folium import Marker
from folium.plugins import MarkerCluster

# ▶ Base map 설정
m = folium.Map(location=[29.5978, -95.3524], tiles='openstreetmap', zoom_start=11)

# ▶Marker cluster (위도, 경도, 제목)
mc = MarkerCluster()
for _, row in df_city.iterrows():
    mc.add_child(
        Marker(location = [row['latitude'], row['longitude']],
              #tooltip = row['street_address']
               popup=row['street_address']                     #tooltip은 마우스를 대면 바로 나오지만, 이건 클릭해야 나옴
              )
    )

m.add_child(mc)

# ▶ Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_00aaeab7ecf273927dc2e70a85d5e23a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_00aaeab7ecf273927dc2e70a85d5e23a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_00aaeab7ecf273927dc2e70a85d5e23a = L.map(
#                 &quot;map_00aaeab7ecf273927dc2e70a85d5e23a&quot;,
#                 {
#                     center: [29.5978, -95.3524],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_312540fb2094e16e899980315cfe09af = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_00aaeab7ecf273927dc2e70a85d5e23a);
#
#
#             var marker_cluster_1e11d004e4d2dd4d1f1b90319aed67d4 = L.markerClusterGroup(
#                 {}
#             );
#             map_00aaeab7ecf273927dc2e70a85d5e23a.addLayer(marker_cluster_1e11d004e4d2dd4d1f1b90319aed67d4);
#
#
#             var marker_4e13633fc3223ae279c70e68cd0bc99a = L.marker(
#                 [33.9048, -89.0011],
#                 {}
#             ).addTo(marker_cluster_1e11d004e4d2dd4d1f1b90319aed67d4);
#
#
#         var popup_00c39096a2ef259e2fca68996a0251a4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_1554149a734fa5f3afff63affb26fa6f = $(`&lt;div id=&quot;html_1554149a734fa5f3afff63affb26fa6f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;686 N Jackson St,&lt;/div&gt;`)[0];
#             popup_00c39096a2ef259e2fca68996a0251a4.setContent(html_1554149a734fa5f3afff63affb26fa6f);
#
#
#         marker_4e13633fc3223ae279c70e68cd0bc99a.bindPopup(popup_00c39096a2ef259e2fca68996a0251a4)
#         ;
#
#
#
#
#             var marker_06f1c29206db143374d163b8ee1bbab9 = L.marker(
#                 [37.32, -91.9592],
#                 {}
#             ).addTo(marker_cluster_1e11d004e4d2dd4d1f1b90319aed67d4);
#
#
#         var popup_5c5b8a183887726dffcfdacebcf97eb7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_80f4b43896a380db07dd0a1ca915c642 = $(`&lt;div id=&quot;html_80f4b43896a380db07dd0a1ca915c642&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;801 S. Sam Houston Blvd.,&lt;/div&gt;`)[0];
#             popup_5c5b8a183887726dffcfdacebcf97eb7.setContent(html_80f4b43896a380db07dd0a1ca915c642);
#
#
#         marker_06f1c29206db143374d163b8ee1bbab9.bindPopup(popup_5c5b8a183887726dffcfdacebcf97eb7)
#         ;
#
#
#
#
#             var marker_78bbac2ffedcd064077b92f67f7eeb08 = L.marker(
#                 [30.0201, -95.3808],
#                 {}
#             ).addTo(marker_cluster_1e11d004e4d2dd4d1f1b90319aed67d4);
#
#
#         var popup_970c25ccbf372dcebdc81f89504081cb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_70a8ad562c5805e4cb7b1e408c261ffc = $(`&lt;div id=&quot;html_70a8ad562c5805e4cb7b1e408c261ffc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3040 FM 1960 E, Ste 152, Cypress Landing S/C&lt;/div&gt;`)[0];
#             popup_970c25ccbf372dcebdc81f89504081cb.setContent(html_70a8ad562c5805e4cb7b1e408c261ffc);
#
#
#         marker_78bbac2ffedcd064077b92f67f7eeb08.bindPopup(popup_970c25ccbf372dcebdc81f89504081cb)
#         ;
#
#
#
#
#             var marker_8a81d47c768dc09eb67049793f8c79ed = L.marker(
#                 [29.8523, -95.1277],
#                 {}
#             ).addTo(marker_cluster_1e11d004e4d2dd4d1f1b90319aed67d4);
#
#
#         var popup_4d1e52fb30864d3e8190441c00b53f42 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_b9ab08a7860a22bebb277cba90643e58 = $(`&lt;div id=&quot;html_b9ab08a7860a22bebb277cba90643e58&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;17225 Crosby Hwy, Shell Truck Stop&lt;/div&gt;`)[0];
#             popup_4d1e52fb30864d3e8190441c00b53f42.setContent(html_b9ab08a7860a22bebb277cba90643e58);
#
#
#         marker_8a81d47c768dc09eb67049793f8c79ed.bindPopup(popup_4d1e52fb30864d3e8190441c00b53f42)
#         ;
#
#
#
#
#             var marker_a3d7fb9479e47b9c7bf04e231dbd4972 = L.marker(
#                 [29.5978, -95.3524],
#                 {}
#             ).addTo(marker_cluster_1e11d004e4d2dd4d1f1b90319aed67d4);
#
#
#         var popup_5e635139d7ff04606e891e47c8702025 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_d49a9a1359dd324188c178b89a5c7098 = $(`&lt;div id

# %% [markdown]
# ## **🥈Session 2**
# **┗ 주소 기반 상권 분석**
# ---

# %% [markdown]
# ### · 밀집도 분석(State)
# ---

# %%
df.head(5)
# Out:
#      name                                  street_address        city state  \
# 0  Subway                           1800 Duke St, Ste 100  Alexandria    VA
# 1  Subway                                   1512 King St,  Alexandria    VA
# 2  Subway                            2361 Eisenhower Ave,  Alexandria    VA
# 3  Subway                      320 King Street, 1st Floor  Alexandria    VA
# 4  Subway  5836 N. Kings Hwy, Suite A, Huntington Station  Alexandria    VA
#
#   zip_code country  latitude  longitude
# 0    22314     USA   38.8043   -77.0611
# 1    22301     USA   38.8062   -77.0565
# 2    22314     USA   38.8012   -77.0691
# 3    22314     USA   38.8045   -77.0433
# 4    22303     USA   38.7903   -77.0769

# %%
# ▶ 밀집도(State), 총 점포수 대비 각 주(State)에 있는 점포수의 밀집도 분석
df_density = pd.DataFrame(df.groupby('state')['street_address'].count())            #count를 통해 state 별 점포 갯수 확인
                                                                                    #원래는 reset_index를 해야함
df_density['total'] = df_density['street_address'].sum()
df_density['density'] = round(df_density['street_address']/df_density['total']*100,2)
df_density.head()
# Out:
#        street_address  total  density
# state
# AK                 63  25533     0.25
# AL                456  25533     1.79
# AR                283  25533     1.11
# AZ                453  25533     1.77
# CA               2590  25533    10.14

# %%
# ▶ 52개 주(State)별 밀집도 표현
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.style.use(['dark_background'])

plt.bar(df_density.index, df_density['density'], label='density');
plt.legend();
plt.gcf().set_size_inches(25, 5);

# %%
# ▶ 52개 주(State)별 밀집도 표현, 내림차순 정렬
# ▶ CA(캘리포니아), ..., DE(델라웨어)
df_density = df_density.sort_values(by=['density'], ascending = False)
plt.bar(df_density.index, df_density['density'], label='density');
plt.legend();
plt.gcf().set_size_inches(25, 5);

# %%
# ▶ 밀집도가 가장 낮은 DE(델라웨어)주 mapping
from folium import Marker
from folium.plugins import MarkerCluster

df_DE = df[df['state']=='DE']

# ▶ Draw a basemap
 #하드코딩으로 숫자를 지정해도 되지만, 이렇게 list형태로 가져와도 됨
m = folium.Map(location=[list(df_DE['latitude'])[0], list(df_DE['longitude'])[0]], tiles='openstreetmap', zoom_start=11)

# ▶ Add  points to the map
mc = MarkerCluster()
for _, row in df_DE.iterrows():
    mc.add_child(
        Marker(location = [row['latitude'], row['longitude']],
               tooltip=row['street_address']
              )
    )

m.add_child(mc)

# ▶ Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d07fe6444254828b72aca54dadfc2914 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d07fe6444254828b72aca54dadfc2914&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d07fe6444254828b72aca54dadfc2914 = L.map(
#                 &quot;map_d07fe6444254828b72aca54dadfc2914&quot;,
#                 {
#                     center: [38.5756, -75.5666],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_740ed273c7c6bc0d09d1a172c061bc5e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d07fe6444254828b72aca54dadfc2914);
#
#
#             var marker_cluster_b8bc33d1b9a9e2ed45e745be3bc37aa4 = L.markerClusterGroup(
#                 {}
#             );
#             map_d07fe6444254828b72aca54dadfc2914.addLayer(marker_cluster_b8bc33d1b9a9e2ed45e745be3bc37aa4);
#
#
#             var marker_1818c4fd6ae64c3f92265acfe2412e5b = L.marker(
#                 [38.5756, -75.5666],
#                 {}
#             ).addTo(marker_cluster_b8bc33d1b9a9e2ed45e745be3bc37aa4);
#
#
#             marker_1818c4fd6ae64c3f92265acfe2412e5b.bindTooltip(
#                 `&lt;div&gt;
#                      30182 Sussex Hwy, Unit 2, Laurel Crossings
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_749538df33b6c352d0a711a80842c209 = L.marker(
#                 [38.646, -75.6213],
#                 {}
#             ).addTo(marker_cluster_b8bc33d1b9a9e2ed45e745be3bc37aa4);
#
#
#             marker_749538df33b6c352d0a711a80842c209.bindTooltip(
#                 `&lt;div&gt;
#                      301 W Stein Hwy,
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_32dd111b2cc393677e9187f53415a3b2 = L.marker(
#                 [38.6613, -75.5922],
#                 {}
#             ).addTo(marker_cluster_b8bc33d1b9a9e2ed45e745be3bc37aa4);
#
#
#             marker_32dd111b2cc393677e9187f53415a3b2.bindTooltip(
#                 `&lt;div&gt;
#                      751 North Dual Highway, Wal-Mart #2460
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_7fc00c1d6bf1bed4be6a904f9ae1404f = L.marker(
#                 [38.7188, -75.5863],
#                 {}
#             ).addTo(marker_cluster_b8bc33d1b9a9e2ed45e745be3bc37aa4);
#
#
#             marker_7fc00c1d6bf1bed4be6a904f9ae1404f.bindTooltip(
#                 `&lt;div&gt;
#                      9577 Bridgeville Park Ctr, U E2, Bridgeville Park Center
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_a6d271a82a8e4f7f37809c74c1cee767 = L.marker(
#                 [38.7033, -75.4036],
#                 {}
#             ).addTo(marker_cluster_b8bc33d1b9a9e2ed45e745be3bc37aa4);
#
#
#             marker_a6d271a82a8e4f7f37809c74c1cee767.bindTooltip(
#                 `&lt;div&gt;
#                      6 College Park Lane, Ste 15
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_02f1ba967055eced81afff3271250004 = L.marker(
#                 [38.7889, -75.3139],
#                 {}
#             ).addTo(marker_cluster_b8bc33d1b9a9e2ed45e745be3bc37aa4);
#
#
#             marker_02f1ba967055eced81afff3271250004.bindTooltip(
#                 `&lt;div&gt;
#                      126 Broadkill Road,
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_0e88d1f3fcd91fc9f57e755c4ec25057 = L.marker(
#                 [38.5875, -75.2984],
#                 {}
#             ).addTo(marker_cluster_b8bc33d1b9a9e2ed45e745be3bc37aa4);
#
#
#             marker_0e88d1f3fcd91fc9f57e755c4ec25057.bindTooltip(
#                 `&lt;div&gt;
#                      28544 DuPont Blvd, Unit 7
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_fcc82d8f7bfb8f09ff63225ad9e1e475 = L.marker(
#                 [38.9289, -75.5662],
#                 {}
#             ).addTo(marker_cluster_b8bc33d1b9a9e2ed45e745be3bc37aa4);
#
#
#             marker_fcc82d8f7bfb8f09ff63225ad9e1e475.bindTooltip(
#                 `&lt;div&gt;

# %% [markdown]
# ### · 밀집도 분석(City)
# ---

# %%
df.head(5)
# Out:
#      name                                  street_address        city state  \
# 0  Subway                           1800 Duke St, Ste 100  Alexandria    VA
# 1  Subway                                   1512 King St,  Alexandria    VA
# 2  Subway                            2361 Eisenhower Ave,  Alexandria    VA
# 3  Subway                      320 King Street, 1st Floor  Alexandria    VA
# 4  Subway  5836 N. Kings Hwy, Suite A, Huntington Station  Alexandria    VA
#
#   zip_code country  latitude  longitude
# 0    22314     USA   38.8043   -77.0611
# 1    22301     USA   38.8062   -77.0565
# 2    22314     USA   38.8012   -77.0691
# 3    22314     USA   38.8045   -77.0433
# 4    22303     USA   38.7903   -77.0769

# %%
# ▶ 밀집도(City), 총 점포수 대비 각 주(State)에 있는 점포수의 밀집도 분석
 #참고로 groupby를 2개의 컬럼으로 만들고 reset_index를 안 하면 2개 컬럼이 index로 생성됨
  #즉, multi index
df_density_city = pd.DataFrame(df.groupby(['state', 'city'])['street_address'].count()).reset_index()
df_density_city.columns=['state', 'city', 'cnt_city']
df_density_city.head(5)
# Out:
#   state         city  cnt_city
# 0    AK    Anchorage        22
# 1    AK       Barrow         1
# 2    AK       Bethel         1
# 3    AK  Denali Park         1
# 4    AK   Dillingham         1

# %%
# ▶ 전체 점포 수 대비 밀집도가 아닌, 각 주(State)에 점포수 대비 밀집도를 계산하기 위해 state별 점포수 계산
df_density_state = pd.DataFrame(df.groupby(['state'])['street_address'].count()).reset_index()
df_density_state.columns = ['state', 'cnt_state']
df_density_state.head(5)
# Out:
#   state  cnt_state
# 0    AK         63
# 1    AL        456
# 2    AR        283
# 3    AZ        453
# 4    CA       2590

# %%
# ▶ 전체 점포 수 대비 밀집도가 아닌, 각 주(State)에 점포수 대비 밀집도를 계산 (※ 상위에서 구한 주별 점포 수를 left join)
df_merge = pd.merge(df_density_city, df_density_state, how = 'left', on = 'state')
df_merge['density'] = (df_merge['cnt_city'] / df_merge['cnt_state']) * 100
df_merge = df_merge.sort_values(by=['density'], ascending=False)
df_merge.head(10)

#즉, city별로 밀집도가 가장 높은 건 washington
# Out:
#      state         city  cnt_city  cnt_state    density
# 1376    DC   Washington        65         69  94.202899
# 6008    NV    Las Vegas       120        218  55.045872
# 2074    HI     Honolulu        44        115  38.260870
# 0       AK    Anchorage        22         63  34.920635
# 5935    NM  Albuquerque        50        176  28.409091
# 5642    NE        Omaha        44        206  21.359223
# 440     AZ      Phoenix        90        453  19.867550
# 8044    SD  Sioux Falls        19         98  19.387755
# 3812    MD    Baltimore        85        471  18.046709
# 5555    ND        Fargo        12         67  17.910448

# %%
df_merge.tail(5)
# Out:
#     state          city  cnt_city  cnt_state  density
# 987    CA  Sierra Madre         1       2590  0.03861
# 990    CA  Solana Beach         1       2590  0.03861
# 991    CA       Soledad         1       2590  0.03861
# 992    CA       Solvang         1       2590  0.03861
# 629    CA     Earlimart         1       2590  0.03861

# %%
# ▶ 도시(City) 밀집도 기준, Top 30
# ▶ Washington, Las Vegas 순으로 도시 밀집도가 높음
df_merge_30h = df_merge.head(30)
plt.bar(df_merge_30h['city'], df_merge_30h['density'], label='top30');
plt.xticks(rotation=-20)
plt.legend()
plt.gcf().set_size_inches(25, 5);

# %%
# ▶ 도시(City) 밀집도 기준, Tail 30
# ▶ 후순위 30개의의 도시들은 밀집도에 큰 차이가 없음
df_merge_30t = df_merge.tail(30)
plt.bar(df_merge_30t['city'], df_merge_30t['density'], label='tail30');
plt.xticks(rotation=-20)
plt.gcf().set_size_inches(25, 5);

# %%
# ▶ 밀집도가 가장 낮은 DE(델라웨어)주 mapping
 #밀집도만 고려한다면 이곳에 상권이 들어가면 좋을 것으로 예상됨
from folium import Marker
from folium.plugins import MarkerCluster

df_DE = df[df['city']=='Sierra Madre']

# ▶ Draw a basemap
m = folium.Map(location=[list(df_DE['latitude'])[0], list(df_DE['longitude'])[0]], tiles='openstreetmap', zoom_start=11)

# ▶ Add  points to the map
mc = MarkerCluster()
for _, row in df_DE.iterrows():
    mc.add_child(
        Marker(location = [row['latitude'], row['longitude']],
               popup=row['street_address']
              )
    )

m.add_child(mc)

# ▶ Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_62408c1429c59c21792f76336fe7b2bd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_62408c1429c59c21792f76336fe7b2bd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_62408c1429c59c21792f76336fe7b2bd = L.map(
#                 &quot;map_62408c1429c59c21792f76336fe7b2bd&quot;,
#                 {
#                     center: [34.162, -118.0559],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a1decbb97ea401a2ad722c5129584d9f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_62408c1429c59c21792f76336fe7b2bd);
#
#
#             var marker_cluster_94b61522a5915a38254fb53198f71edb = L.markerClusterGroup(
#                 {}
#             );
#             map_62408c1429c59c21792f76336fe7b2bd.addLayer(marker_cluster_94b61522a5915a38254fb53198f71edb);
#
#
#             var marker_994dd6c87221bf0a7f24591095ea5666 = L.marker(
#                 [34.162, -118.0559],
#                 {}
#             ).addTo(marker_cluster_94b61522a5915a38254fb53198f71edb);
#
#
#         var popup_34be533660e06ab28b3712a4f915cb67 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_0e723b827b98636334a7b36fdc65ca9c = $(`&lt;div id=&quot;html_0e723b827b98636334a7b36fdc65ca9c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;148 W Sierra Madre Blvd,&lt;/div&gt;`)[0];
#             popup_34be533660e06ab28b3712a4f915cb67.setContent(html_0e723b827b98636334a7b36fdc65ca9c);
#
#
#         marker_994dd6c87221bf0a7f24591095ea5666.bindPopup(popup_34be533660e06ab28b3712a4f915cb67)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## **🥇Session 3**
# **┗ 신규 진입 상권 탐색**
# ---

# %% [markdown]
# ### · 상권 전략 기획(1)
# ---
# * 주(State)의 상권 밀집도가 높다는 건 그 만큼 소비할 수 있는 인구수가 많아서 많이 들어갔을 것이라고 가설
# * 주(State) 밀집도가 높으면서, 도시(City) 밀집도가 낮은 지역을 목표 (사람이 많은 주 중에서, 상권이 적은 도시에 들어가는 전략 생각)
#
# * 사실 이 가설은 다른 변수를 고려하지 않은 추측성이 높은 가설이기 때문에 실제에서는 이렇게 까지 비약으로 생각하면 안됨

# %%
# ▶ 기존 산출했던 주(State) 밀집도
df_density.columns = ['cnt_state', 'total', 'density_state']
df_density = df_density.reset_index()
df_density.head(5)
# Out:
#   state  cnt_state  total  density_state
# 0    CA       2590  25533          10.14
# 1    TX       2194  25533           8.59
# 2    FL       1490  25533           5.84
# 3    OH       1171  25533           4.59
# 4    IL       1110  25533           4.35

# %%
# ▶ state 랑 밀집도만 가져오기
df_density = df_density[['state', 'density_state']]
df_density.head(5)
# Out:
#   state  density_state
# 0    CA          10.14
# 1    TX           8.59
# 2    FL           5.84
# 3    OH           4.59
# 4    IL           4.35

# %%
df_merge.head()
# Out:
#      state         city  cnt_city  cnt_state    density
# 1376    DC   Washington        65         69  94.202899
# 6008    NV    Las Vegas       120        218  55.045872
# 2074    HI     Honolulu        44        115  38.260870
# 0       AK    Anchorage        22         63  34.920635
# 5935    NM  Albuquerque        50        176  28.409091

# %%
# ▶ 도시 밀집도 데이터 재정비
df_merge.columns = ['state', 'city', 'cnt_city', 'cnt_state', 'density_city']
df_merge = df_merge.reset_index(drop=True)
df_merge.head(5)
# Out:
#   state         city  cnt_city  cnt_state  density_city
# 0    DC   Washington        65         69     94.202899
# 1    NV    Las Vegas       120        218     55.045872
# 2    HI     Honolulu        44        115     38.260870
# 3    AK    Anchorage        22         63     34.920635
# 4    NM  Albuquerque        50        176     28.409091

# %%
# ▶ 도시(City) 밀집도 데이터와 주(Staet) 밀집도 left join
df_merge = pd.merge(df_merge, df_density, how = 'left', on = 'state')
df_merge
# Out:
#      state          city  cnt_city  cnt_state  density_city  density_state
# 0       DC    Washington        65         69     94.202899           0.27
# 1       NV     Las Vegas       120        218     55.045872           0.85
# 2       HI      Honolulu        44        115     38.260870           0.45
# 3       AK     Anchorage        22         63     34.920635           0.25
# 4       NM   Albuquerque        50        176     28.409091           0.69
# ...    ...           ...       ...        ...           ...            ...
# 9946    CA  Sierra Madre         1       2590      0.038610          10.14
# 9947    CA  Solana Beach         1       2590      0.038610          10.14
# 9948    CA       Soledad         1       2590      0.038610          10.14
# 9949    CA       Solvang         1       2590      0.038610          10.14
# 9950    CA     Earlimart         1       2590      0.038610          10.14
#
# [9951 rows x 6 columns]

# %%
# ▶ 전략 기획에서 정의한, 주 밀집도는 높으면서 도시 밀집도는 낮은 지역 탐색
df_merge.sort_values(by=['density_state', 'density_city'], ascending = [False, True]).head(10)

 #캘리포니아주에 대부분에 도시들이 도시 당 1개의 상권을 보유하고 있는 것 발견
# Out:
#      state           city  cnt_city  cnt_state  density_city  density_state
# 9701    CA       Monrovia         1       2590       0.03861          10.14
# 9702    CA   Mount Shasta         1       2590       0.03861          10.14
# 9703    CA     Marin City         1       2590       0.03861          10.14
# 9704    CA       Oak Park         1       2590       0.03861          10.14
# 9705    CA       Maricopa         1       2590       0.03861          10.14
# 9706    CA         Marina         1       2590       0.03861          10.14
# 9707    CA  Mammoth Lakes         1       2590       0.03861          10.14
# 9708    CA      Morro Bay         1       2590       0.03861          10.14
# 9709    CA       Montrose         1       2590       0.03861          10.14
# 9710    CA         Mojave         1       2590       0.03861          10.14

# %%
# ▶ 1순위 후보 지역
 #캘리포니아주의 monrovia 도시
df[(df['state']=='CA') & (df['city']=='Monrovia')]
# Out:
#         name                             street_address      city state  \
# 8535  Subway  119 W. Foothill Blvd, #B, Foothill Center  Monrovia    CA
#
#      zip_code country  latitude  longitude
# 8535    91016     USA   34.1515  -118.0018

# %%
from folium import Marker
from folium.plugins import MarkerCluster

df_DE = df[df['state']=='CA']

# ▶ Draw a basemap
m = folium.Map(location=[34.1515, -118.0018], tiles='openstreetmap', zoom_start=11)

# ▶ Add  points to the map
mc = MarkerCluster()
for _, row in df_DE.iterrows():
    mc.add_child(
        Marker(location = [row['latitude'], row['longitude']],
               popup=row['street_address']
              )
    )

m.add_child(mc)

# ▶ 1순위 후보지역 Circle Marker 추가
folium.CircleMarker(
  [34.1515, -118.0018],
  radius=100,
  color='green',
  fill_color='#fffggg',
  popup='New_in'
).add_to(m)

# ▶ Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cbf1ef6ee5b6b7611282f8897dd7f156 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cbf1ef6ee5b6b7611282f8897dd7f156&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cbf1ef6ee5b6b7611282f8897dd7f156 = L.map(
#                 &quot;map_cbf1ef6ee5b6b7611282f8897dd7f156&quot;,
#                 {
#                     center: [34.1515, -118.0018],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_109136bb6a8a60565c7bb3f926c10669 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_cbf1ef6ee5b6b7611282f8897dd7f156);
#
#
#             var marker_cluster_d59468f265b0cf2a13039434560d459f = L.markerClusterGroup(
#                 {}
#             );
#             map_cbf1ef6ee5b6b7611282f8897dd7f156.addLayer(marker_cluster_d59468f265b0cf2a13039434560d459f);
#
#
#             var marker_decaf35b33fbb83cd7435c86f237e568 = L.marker(
#                 [34.8509, -114.6241],
#                 {}
#             ).addTo(marker_cluster_d59468f265b0cf2a13039434560d459f);
#
#
#         var popup_9b5b50fcb001028b3fb7ed3bdee6e567 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_b05fbd1662f897a826ad89f11bf5617b = $(`&lt;div id=&quot;html_b05fbd1662f897a826ad89f11bf5617b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2451 Needles Hwy, Shell Gas Station/C-Store&lt;/div&gt;`)[0];
#             popup_9b5b50fcb001028b3fb7ed3bdee6e567.setContent(html_b05fbd1662f897a826ad89f11bf5617b);
#
#
#         marker_decaf35b33fbb83cd7435c86f237e568.bindPopup(popup_9b5b50fcb001028b3fb7ed3bdee6e567)
#         ;
#
#
#
#
#             var marker_c7557a4739065d231d65fb1a188f849c = L.marker(
#                 [33.6065, -114.603],
#                 {}
#             ).addTo(marker_cluster_d59468f265b0cf2a13039434560d459f);
#
#
#         var popup_36051568ba1a7645db32f2a03296083e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_04e6530eb8c508d90f0861a85e1cb759 = $(`&lt;div id=&quot;html_04e6530eb8c508d90f0861a85e1cb759&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;650 W. Donlon Street,&lt;/div&gt;`)[0];
#             popup_36051568ba1a7645db32f2a03296083e.setContent(html_04e6530eb8c508d90f0861a85e1cb759);
#
#
#         marker_c7557a4739065d231d65fb1a188f849c.bindPopup(popup_36051568ba1a7645db32f2a03296083e)
#         ;
#
#
#
#
#             var marker_f8ef8a5d63a7defb0df9584b21186c11 = L.marker(
#                 [32.9786, -115.5481],
#                 {}
#             ).addTo(marker_cluster_d59468f265b0cf2a13039434560d459f);
#
#
#         var popup_6c928e1e9a4a580c37ec5b995708d56e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_422e70df6edac7b9999a7e00fd91d268 = $(`&lt;div id=&quot;html_422e70df6edac7b9999a7e00fd91d268&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;407 W Main Street,&lt;/div&gt;`)[0];
#             popup_6c928e1e9a4a580c37ec5b995708d56e.setContent(html_422e70df6edac7b9999a7e00fd91d268);
#
#
#         marker_f8ef8a5d63a7defb0df9584b21186c11.bindPopup(popup_6c928e1e9a4a580c37ec5b995708d56e)
#         ;
#
#
#
#
#             var marker_299b7e7bfd6860cb2dac2180e425eee6 = L.marker(
#                 [32.9624, -115.5465],
#                 {}
#             ).addTo(marker_cluster_d59468f265b0cf2a13039434560d459f);
#
#
#         var popup_aec72c4aae10322623d31ff80979287e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_f738ef02c4a416ecff01b7e39fda677b = $(`&lt;div id=&quot;html_f738ef02c4a416ecff01b7e39fda677b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;250 W Wildcat Dr, Wal-Mart# 5335&lt;/div&gt;`)[0];
#             popup_aec72c4aae10322623d31ff80979287e.setContent(html_f738ef02c4a416ecff01b7e39fda677b);
#
#
#         marker_299b7e7bfd6860cb2dac2180e425eee6.bindPopup(popup_aec72c4aae10322623d31ff80979287e)
#         ;
#
#
#
#
#             var marker_b1501f2c24a156955ad42d7c131e7399 = L.marker(
#                 [33.0369, -115.6296],
#                 {}
#             ).addTo(marker_cluster_d59468f265b0cf2a13039434560d459f);
#
#
#         var popup_88130f6c25e906f2a2260bb7da7e3ebf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_6c61ed39cd7332a7c5309d191fad4bd7 = $(`&lt;div i

# %% [markdown]
# ### · 상권 전략 기획(2)
# ---
# * Hwy(Highway) 타겟으로 고속도로에 밀집도가 낮은 지역을 후보지로 탐색

# %%
df.head(10)
# Out:
#      name                                     street_address        city  \
# 0  Subway                              1800 Duke St, Ste 100  Alexandria
# 1  Subway                                      1512 King St,  Alexandria
# 2  Subway                               2361 Eisenhower Ave,  Alexandria
# 3  Subway                         320 King Street, 1st Floor  Alexandria
# 4  Subway     5836 N. Kings Hwy, Suite A, Huntington Station  Alexandria
# 5  Subway    101 Independence Ave S. E., Library of Congress  Washington
# 6  Subway  Rayburn Bldg., 45 Independence Ave. SW, US Hou...  Washington
# 7  Subway                                     430 8th St SE,  Washington
# 8  Subway  1100 New Jersey Ave SE, 1st Floor, Federal Gat...  Washington
# 9  Subway             50 Massachusetts Ave NE, Union Station  Washington
#
#   state zip_code country  latitude  longitude
# 0    VA    22314     USA   38.8043   -77.0611
# 1    VA    22301     USA   38.8062   -77.0565
# 2    VA    22314     USA   38.8012   -77.0691
# 3    VA    22314     USA   38.8045   -77.0433
# 4    VA    22303     USA   38.7903   -77.0769
# 5    DC    20540     USA   38.8871   -77.0041
# 6    DC    20515     USA   38.8870   -77.0106
# 7    DC    20003     USA   38.8829   -76.9946
# 8    DC    20003     USA   38.8770   -77.0037
# 9    DC    20002     USA   38.8971   -77.0064

# %%
# ▶ 주소지 기준 Hwy가 포함된 데이터만 Filter
 #Hwy: highway
df_hwy = df[df['street_address'].str.contains('Hwy')]
df_hwy.head(10)
# Out:
#       name                                     street_address        city  \
# 4   Subway     5836 N. Kings Hwy, Suite A, Huntington Station  Alexandria
# 17  Subway  3825 Jefferson Davis Hwy, Ste B, Potomac Yard ...  Alexandria
# 29  Subway         30182 Sussex Hwy, Unit 2, Laurel Crossings      Laurel
# 30  Subway                                   301 W Stein Hwy,     Seaford
# 33  Subway                  8600 Ocean Hwy, Ste 4, Tiger Mart      Delmar
# 48  Subway  16819 S. DuPont Hwy., Suite 100, Mattlind Squa...  Harrington
# 49  Subway  11425 S.Dupont Hwy, N Rt 13 & Rt 12, Felton Go...      Felton
# 50  Subway                          905 N Dupont Hwy, Ste 101     Milford
# 51  Subway                           5502 S Dupont Hwy, Ste 3       Dover
# 62  Subway  1200 Dupont Hwy, MLK Jr Student Center, Delawa...       Dover
#
#    state zip_code country  latitude  longitude
# 4     VA    22303     USA   38.7903   -77.0769
# 17    VA    22305     USA   38.8389   -77.0516
# 29    DE    19956     USA   38.5756   -75.5666
# 30    DE    19973     USA   38.6460   -75.6213
# 33    MD    21875     USA   38.4292   -75.5651
# 48    DE    19952     USA   38.9289   -75.5662
# 49    DE    19943     USA   39.0076   -75.5687
# 50    DE    19963     USA   38.9279   -75.4332
# 51    DE    19901     USA   39.0727   -75.5533
# 62    DE    19901     USA   39.1884   -75.5400

# %%
# ▶ 주(State) 기준으로 고속도로에 가장 적은 매장을 가지고 있는 주(State) 탐색
 #reset_index를 안 하면 groupby의 대상인 state가 index가 됨
pd.DataFrame(df_hwy.groupby('state')['street_address'].count()).reset_index().sort_values(by=['street_address'], ascending=True).head(10)
#ME state가 가장 적은 것을 알 수 있음
# Out:
#    state  street_address
# 20    ME               1
# 38    RI               3
# 27    ND               4
# 47    WV               4
# 18    MA               4
# 48    WY               5
# 30    NJ               7
# 6     CT               7
# 43    UT               8
# 40    SD               8

# %%
df_hwy[df_hwy['state']=='ME']
# Out:
#        name      street_address       city state    zip_code country  \
# 816  Subway  1560 Atlantic Hwy,  Waldoboro    ME  04572-9801     USA
#
#      latitude  longitude
# 816   44.0964   -69.3736

# %%
from folium import Marker
from folium.plugins import MarkerCluster

df_DE = df[df['state']=='ME']

# ▶ Draw a basemap
 #위에서 찾은 데이터 기반으로 위도 경도 설정
m = folium.Map(location=[44.0964, -69.3736], tiles='openstreetmap', zoom_start=11)

# ▶ Add  points to the map
mc = MarkerCluster()
for _, row in df_DE.iterrows():
    mc.add_child(
        Marker(location = [row['latitude'], row['longitude']],
               popup=row['street_address']
              )
    )

m.add_child(mc)

# ▶ 1순위 후보지 Circle Marker 추가
folium.CircleMarker(
  [44.0964, -69.3736],
  radius=100,
  color='#ffffgg',
  fill_color='red',
  popup='New_in'
).add_to(m)

# ▶ Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_84a1abbba76b7076675384a9f46f9759 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_84a1abbba76b7076675384a9f46f9759&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_84a1abbba76b7076675384a9f46f9759 = L.map(
#                 &quot;map_84a1abbba76b7076675384a9f46f9759&quot;,
#                 {
#                     center: [44.0964, -69.3736],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4d3ee6a060eb422f02981860e977c8b6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_84a1abbba76b7076675384a9f46f9759);
#
#
#             var marker_cluster_698cdc483a0834075295371cafbbd854 = L.markerClusterGroup(
#                 {}
#             );
#             map_84a1abbba76b7076675384a9f46f9759.addLayer(marker_cluster_698cdc483a0834075295371cafbbd854);
#
#
#             var marker_c816b2a5d16a331a0381cc00468e9b47 = L.marker(
#                 [44.5589, -69.6335],
#                 {}
#             ).addTo(marker_cluster_698cdc483a0834075295371cafbbd854);
#
#
#         var popup_19976dac4bdc5f4b11db460d9444a8b5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_cf3d6e5a8f4f08a34f56971a7aee68b1 = $(`&lt;div id=&quot;html_cf3d6e5a8f4f08a34f56971a7aee68b1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;150 Elm Plaza, Elm Plaza Shopping Center&lt;/div&gt;`)[0];
#             popup_19976dac4bdc5f4b11db460d9444a8b5.setContent(html_cf3d6e5a8f4f08a34f56971a7aee68b1);
#
#
#         marker_c816b2a5d16a331a0381cc00468e9b47.bindPopup(popup_19976dac4bdc5f4b11db460d9444a8b5)
#         ;
#
#
#
#
#             var marker_383bf6fce5431331e1449df3f173d463 = L.marker(
#                 [44.537, -69.6275],
#                 {}
#             ).addTo(marker_cluster_698cdc483a0834075295371cafbbd854);
#
#
#         var popup_7526a0d3fda74171f1f2d4b753a48378 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_7b9b45491b8f5051972e4ba4d7a96401 = $(`&lt;div id=&quot;html_7b9b45491b8f5051972e4ba4d7a96401&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1 Cushman Rd, Halifax Crossing&lt;/div&gt;`)[0];
#             popup_7526a0d3fda74171f1f2d4b753a48378.setContent(html_7b9b45491b8f5051972e4ba4d7a96401);
#
#
#         marker_383bf6fce5431331e1449df3f173d463.bindPopup(popup_7526a0d3fda74171f1f2d4b753a48378)
#         ;
#
#
#
#
#             var marker_f0650f0fe3e13166889342f14d06fdae = L.marker(
#                 [44.5443, -69.6725],
#                 {}
#             ).addTo(marker_cluster_698cdc483a0834075295371cafbbd854);
#
#
#         var popup_dd528bceddb37e68fe6692f2791e9067 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_1db0ea17dae9f1a7257c4ba92f650e2e = $(`&lt;div id=&quot;html_1db0ea17dae9f1a7257c4ba92f650e2e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;350 Kennedy Memorial Dr,&lt;/div&gt;`)[0];
#             popup_dd528bceddb37e68fe6692f2791e9067.setContent(html_1db0ea17dae9f1a7257c4ba92f650e2e);
#
#
#         marker_f0650f0fe3e13166889342f14d06fdae.bindPopup(popup_dd528bceddb37e68fe6692f2791e9067)
#         ;
#
#
#
#
#             var marker_d3da9fd4d252529266abdd3172860690 = L.marker(
#                 [44.5948, -69.6179],
#                 {}
#             ).addTo(marker_cluster_698cdc483a0834075295371cafbbd854);
#
#
#         var popup_b06ef568a626f1777dac547652ec56ad = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_11c58a8419c5baffc49cd40d851eab07 = $(`&lt;div id=&quot;html_11c58a8419c5baffc49cd40d851eab07&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;204 Center Rd, Located Inside Circle K&lt;/div&gt;`)[0];
#             popup_b06ef568a626f1777dac547652ec56ad.setContent(html_11c58a8419c5baffc49cd40d851eab07);
#
#
#         marker_d3da9fd4d252529266abdd3172860690.bindPopup(popup_b06ef568a626f1777dac547652ec56ad)
#         ;
#
#
#
#
#             var marker_865576d9aa3802c606a4ff1e9531535d = L.marker(
#                 [44.5477, -69.7185],
#                 {}
#             ).addTo(marker_cluster_698cdc483a0834075295371cafbbd854);
#
#
#         var popup_d37b46f6bfb5f59116c8dc51b4a6b146 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_c882df6e0777903d08fe3976a6d3742f =
